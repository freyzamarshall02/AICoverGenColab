# %% [markdown]
# <a href="https://colab.research.google.com/github/freyzamarshall02/AICoverGenColab/blob/main/AICoverGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AICoverGen Mod WebUI Version Colab

# %%
#@title Changing Python Runtime to 3.10 (Cell 1)
# !wget -O py310.sh https://raw.githubusercontent.com/j3soon/colab-python-version/main/scripts/py310.sh > /dev/null 2>&1
# !bash py310.sh > /dev/null 2>&1

# Check if python setup was ready
import subprocess
import sys # Import sys module

result = subprocess.run(['python', '--version'], capture_output=True, text=True)
version_output = result.stdout.strip()

if "Python 3.10.16" in version_output:
    print("\033[1m\033[92mPython 3.10 Ready!\033[0m") # Bold Green
else:
    print("\n" + "=" * 80)
    print("🚨🚨🚨  IMPORTANT ACTION REQUIRED  🚨🚨🚨\n")
    print("❌ PYTHON VERSION IS NOT 3.10 ❌\n")
    print("👉 You don't refresh the page yet.")
    print("👉 Please REFRESH the page now and run again.\n")
    print("=" * 80 + "\n")
    sys.exit(1) # Exit with an error code

# %%
#@title Clone repository (Cell 2)
from IPython.display import clear_output, Javascript
import codecs
import threading
import os

# Check if python setup was ready
import subprocess
import sys # Import sys module

result = subprocess.run(['python', '--version'], capture_output=True, text=True)
version_output = result.stdout.strip()

if "Python 3.10.16" in version_output:
    print("\033[1m\033[92mPython 3.10 Ready!\033[0m") # Bold Green
else:
    print("\n" + "=" * 80)
    print("🚨🚨🚨  IMPORTANT ACTION REQUIRED  🚨🚨🚨\n")
    print("❌ PYTHON VERSION IS NOT 3.10 ❌\n")
    print("👉 You don't refresh the page yet.")
    print("👉 Please REFRESH the page now and run again.\n")
    print("=" * 80 + "\n")
    sys.exit(1) # Exit with an error code

# Install AICoverGen
print("\n" + "=" * 60)
print("🔄 Installing AICoverGen...")
print("=" * 60)
# !sudo apt -y update
# !apt-get install -y aria2 > /dev/null 2>&1
# !aria2c -x 16 -s 16 -k 1M \
--summary-interval=5 \
--console-log-level=warn \
-o ai_cover.zip \
https://huggingface.co/freyza/ai_cover/resolve/main/ai_cover.zip

os.chdir('/content')
zip_path = "/content/ai_cover.zip"
extract_path = "/content"

# Unzip the downloaded file
# !unzip -q -o /content/ai_cover.zip -d /content

# Remove the zip file after extraction
# !rm /content/ai_cover.zip

# %cd /content/ai_cover/src
clear_output()
# Installing some dependencies
print("\n" + "=" * 60)
print("🔄 Installing Some Dependencies...")
print("=" * 60)
# !pip install -q pyngrok
clear_output()
print("Finished Updating")
# !sudo apt -y install sox
# Tags
print('\033[32m\033[1m\033[3mAICoverGen Modded By Ryusui Kagaku Notebook By FreyzaMarshall\033[0m')
print("Done Cloning Repository")

# %%
#@title Start (Cell 3)
#@markdown---
cd=codecs.decode('/pbagrag/nv_pbire','rot_13')
# %cd $cd
import time
import codecs
runpice=codecs.decode('fep/eha.cl','rot_13')
Tunnel = "Gradio" #@param ['Cloudflared','Gradio']
if Tunnel == "Gradio":
  # !python $runpice --share
else:
  # !curl -LO https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
  # !dpkg -i cloudflared-linux-amd64.deb
  # !rm -rf nohup.out
  # !nohup cloudflared tunnel --url localhost:7860 &
  clear_output()
  time.sleep(5)
  print("\033[1m\033[3m\033[93mPublic URL\033[0m")
  # !grep -oE "https://[a-zA-Z0-9.-]+\.trycloudflare\.com" nohup.out
  print("\033[1m\033[91mWait until Local URL Started\033[0m")
  # !python $runpice

# %% [markdown]
# ## Experiment

# %%
#@title Audio downloader
import os
import subprocess
from IPython.display import Audio

# Define the directory and make it if it doesn't exist
audio_dir = '/content/song_input'
if not os.path.exists(audio_dir):
    os.makedirs(audio_dir)

# %cd /content/song_input

# Change directory to where you want to save the audio
os.chdir(audio_dir)

# Use wget to download the audio from the provided URL
audio_url = ""  # @param {type:"string"}
subprocess.call(['wget', '-O', 'audio_file.mp3', audio_url])

# Verify the audio file is downloaded
print(os.listdir(audio_dir))
